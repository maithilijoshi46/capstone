# %%
import pandas as pd
import numpy as np
import sys
from scipy import sparse
#0 is good, 1 is bad.
from sklearn.metrics.pairwise import pairwise_distances

# %%
#reading in data
df = pd.read_csv('../data/priors_sample.csv')

# %% [markdown]
# # Filter data by reorders
#
# for users that have re-ordered, what should they order next based on their order history

# %%
#Reorders only
reordered = df[df.reordered == 1]
reordered.head(1)
# Out:
#    Unnamed: 0  product_id  aisle_id  department_id  order_id  \
# 1          26           1        61             19     49769
#
#    add_to_cart_order  reordered  user_id  order_number  order_dow  \
# 1                  4        1.0    45784             4          0
#
#    order_hour_of_day  days_since_prior_order  average_orders  \
# 1                 20                     7.0             0.0
#
#    average_order_dow  average_order_hour  weekend  rate_reordered  aisle_cat  \
# 1                0.0                 0.0        1            0.25          0
#
#    dept_cat  product_cat
# 1         0          NaN

# %%
#reordered.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
reordered.describe()
# Out:
#          Unnamed: 0     product_id       aisle_id  department_id  \
# count  3.336810e+05  333681.000000  333681.000000  333681.000000
# mean   1.804222e+06   25651.859177      71.409373       9.736662
# std    1.033720e+06   14027.276396      38.246004       6.317398
# min    2.600000e+01       1.000000       1.000000       1.000000
# 25%    9.098560e+05   13646.000000      31.000000       4.000000
# 50%    1.788066e+06   25072.000000      83.000000       7.000000
# 75%    2.694935e+06   37825.000000     107.000000      16.000000
# max    3.597575e+06   49686.000000     134.000000      21.000000
#
#             order_id  add_to_cart_order  reordered        user_id  \
# count  333681.000000      333681.000000   333681.0  333681.000000
# mean   244838.556328           7.548590        1.0   78802.232941
# std    141671.738063           6.575117        0.0   46349.294729
# min         5.000000           1.000000        1.0       1.000000
# ...

# %%
pivot = reordered.pivot_table(index = 'product_name', 
                                columns = 'product_id', 
                                values = 'reordered')

pivot.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-9313cd1ceafb> in <module>
#       1 pivot = reordered.pivot_table(index = 'product_name',
#       2                                 columns = 'product_id',
# ----> 3                                 values = 'reordered')
#       4
#       5 pivot.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# ...

# %%
pivot_sparce = sparse.csr_matrix(pivot.fillna(0))

# %%
recommend = pairwise_distances(pivot_sparce, metric = 'cosine')
recommend

# %%
recommend_df = pd.DataFrame(recommend, columns = pivot.index,
                           index = pivot.index)

recommend_df.head()

# %%
#reordered.product_name[3000:4000]

# %%
recommend_df['#4 Natural Brown Coffee Filters'].sort_values()[1:11]
